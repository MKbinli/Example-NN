# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from datetime import datetime, timedelta
from tensorflow import keras

# %% [markdown]
# # DATA PREPARATION

# %%
#Read file from csv to pandas DataFrame
dataDf=pd.read_csv("municipality_bus_utilization.csv", na_values = "?")
#Code refactoring
dataset=dataDf.copy()

# %%
#Check the dataset
dataset.head(20)
# Out:
#               timestamp  municipality_id  usage  total_capacity
# 0   2017-06-04 07:59:42                9    454            1332
# 1   2017-06-04 07:59:42                8    556            2947
# 2   2017-06-04 07:59:42                4   1090            3893
# 3   2017-06-04 07:59:42                0    204            2813
# 4   2017-06-04 07:59:42                7    718            2019
# 5   2017-06-04 07:59:42                5     70             587
# 6   2017-06-04 07:59:42                2    273             697
# 7   2017-06-04 07:59:42                1    129             397
# 8   2017-06-04 07:59:42                6    597            3113
# 9   2017-06-04 07:59:42                3    623            1930
# 10  2017-06-04 08:25:42                2    311             697
# 11  2017-06-04 08:25:42                9    487            1332
# 12  2017-06-04 08:25:42                6    687            3113
# 13  2017-06-04 08:25:42                7    789            2019
# 14  2017-06-04 08:25:42                4   1476            3893
# 15  2017-06-04 08:25:42                8    674            2947
# 16  2017-06-04 08:25:42                5     73             587
# 17  2017-06-04 08:25:42                3    770            1930
# 18  2017-06-04 08:25:42                0    247            2813
# 19  2017-06-04 08:25:42                1    138             397

# %%
#Check for NaN values
dataset.isna().sum()
# Out:
# timestamp          0
# municipality_id    0
# usage              0
# total_capacity     0
# dtype: int64

# %%
#Convert Datetime data to timestamp in seconds
dataset["timestampSeconds"]=pd.to_datetime(pd.to_datetime(dataset["timestamp"]).dt.strftime('%Y-%m-%d %H:00:00')).map(pd.Timestamp.timestamp).astype(int)
#Make sure that dataset is sorted by timestamp and then municipality_id in the group
dataset=dataset.sort_values(by=["timestampSeconds","municipality_id"])
dataset.reset_index(drop=True, inplace=True)

# %%
#Check for logical mistakes
dataset[dataset.usage > dataset.total_capacity]
# Out:
#                  timestamp  municipality_id  usage  total_capacity  \
# 7612   2017-07-17 12:04:02                1    399             397
# 7613   2017-07-17 12:31:03                1    401             397
# 7632   2017-07-17 13:04:03                1    399             397
# 7633   2017-07-17 13:31:03                1    403             397
# 7653   2017-07-17 14:04:03                1    403             397
# ...                    ...              ...    ...             ...
# 13012  2017-08-19 14:03:31                1    408             397
# 13013  2017-08-19 14:30:33                1    410             397
# 13032  2017-08-19 15:03:34                1    408             397
# 13033  2017-08-19 15:29:33                1    411             397
# 13052  2017-08-19 16:03:35                1    401             397
#
#        timestampSeconds
# 7612         1500292800
# 7613         1500292800
# 7632         1500296400
# 7633         1500296400
# 7653         1500300000
# ...                 ...
# 13012        1503151200
# 13013        1503151200
# 13032        1503154800
# 13033        1503154800
# 13052        1503158400
#
# [229 rows x 5 columns]

# %%
#It seems 229 data exceeds total_capacity that is not possible, so we will change "usage value" of illegal ones as total capacitiy
dataset.loc[dataset.usage > dataset.total_capacity,"usage"]=dataset.loc[dataset.usage > dataset.total_capacity,"total_capacity"]

# %%
#Let'check out any strange values inside the data
dataset[dataset.usage < 0]
# Out:
# Empty DataFrame
# Columns: [timestamp, municipality_id, usage, total_capacity, timestampSeconds]
# Index: []

# %%
dataset[dataset.total_capacity <= 0]
# Out:
# Empty DataFrame
# Columns: [timestamp, municipality_id, usage, total_capacity, timestampSeconds]
# Index: []

# %%
dataset[dataset.municipality_id < 0]
# Out:
# Empty DataFrame
# Columns: [timestamp, municipality_id, usage, total_capacity, timestampSeconds]
# Index: []

# %%
dataset[dataset.municipality_id > 9]
# Out:
# Empty DataFrame
# Columns: [timestamp, municipality_id, usage, total_capacity, timestampSeconds]
# Index: []

# %%
#Function checks missing rows, if exists, it fills with previous one day (filling with previous strategy).
def anyMissingRows(df):
    checkDf=df.copy()
    firstTimestamp=checkDf.at[0,"timestampSeconds"]
    lastTimestamp=checkDf.at[len(checkDf)-1,"timestampSeconds"]
    timeDifference=3600#1 hour equals to 3600 seconds
    timeDifferenceOneDay=3600*24
    lastTimestamp=lastTimestamp+timeDifference
    for timeStmp in range(firstTimestamp,lastTimestamp,timeDifference):
        numberOfBus=len(checkDf[checkDf.timestampSeconds==timeStmp])
        if(numberOfBus==0):
            #Value is missing in this specific time. We apply that filling missing value with previous but 24 hours before
            fillingData=checkDf[checkDf.timestampSeconds == timeStmp-timeDifferenceOneDay].copy()
            if(len(fillingData)<= 0):#If 1 day before not exists
                fillingData=checkDf[checkDf.timestampSeconds == timeStmp-timeDifference].copy()
            fillingData["timestampSeconds"]=timeStmp
            fillingData["timestamp"]=pd.to_datetime(fillingData["timestampSeconds"],unit="s")
            checkDf=pd.concat([checkDf,fillingData],axis=0)
            checkDf.reset_index(drop=True, inplace=True)
        
    checkDf=checkDf.sort_values(by=["timestampSeconds","municipality_id"])
    checkDf.reset_index(drop=True, inplace=True)

    return checkDf

# %%
dataset=anyMissingRows(dataset)

# %%
#Now all hourly timestamp includes at least 10 municipalities, we will eliminate 20 buses to 10 buses by choosing max value of eachother.  
dataset
# Out:
#                  timestamp  municipality_id  usage  total_capacity  \
# 0      2017-06-04 07:59:42                0    204            2813
# 1      2017-06-04 07:59:42                1    129             397
# 2      2017-06-04 07:59:42                2    273             697
# 3      2017-06-04 07:59:42                3    623            1930
# 4      2017-06-04 07:59:42                4   1090            3893
# ...                    ...              ...    ...             ...
# 35735  2017-08-19 16:30:35                7   1354            2019
# 35736  2017-08-19 16:03:35                8   1253            2947
# 35737  2017-08-19 16:30:35                8   1193            2947
# 35738  2017-08-19 16:03:35                9    879            1332
# 35739  2017-08-19 16:30:35                9    815            1332
#
#        timestampSeconds
# 0            1496559600
# 1            1496559600
# 2            1496559600
# 3            1496559600
# 4            1496559600
# ...                 ...
# 35735        1503158400
# 35736        1503158400
# 35737        1503158400
# 35738        1503158400
# 35739        1503158400
#
# [35740 rows x 5 columns]

# %%
#Find the maximum usage in a hour for any municipality_id
def busUsageMax(df):
    checkDf=df.copy()
    busUsageMaxDf=pd.DataFrame(columns=df.columns)
    firstTimestamp=checkDf.at[0,"timestampSeconds"]
    lastTimestamp=checkDf.at[len(checkDf)-1,"timestampSeconds"]
    timeDifference=3600#1 hour equals to 3600 seconds
    lastTimestamp=lastTimestamp+timeDifference
    busNumbers=list(range(0,10))
    for timeStmp in range(firstTimestamp,lastTimestamp,timeDifference):
        tempDf=checkDf[checkDf.timestampSeconds==timeStmp].copy()
        for bus in busNumbers:
            newdf=tempDf[tempDf.municipality_id==bus]
            newdf=newdf[newdf.usage==tempDf.loc[tempDf.municipality_id==bus,"usage"].max()]
            if(len(newdf)>1):#More than one values can be same
                busUsageMaxDf=busUsageMaxDf.append(newdf.iloc[0])
            else:
                busUsageMaxDf=busUsageMaxDf.append(newdf)
        
    busUsageMaxDf=busUsageMaxDf.sort_values(by=["timestampSeconds","municipality_id"])
    busUsageMaxDf.reset_index(drop=True, inplace=True)

    return busUsageMaxDf

# %%
#Hence you can aggregate the two measurements for an hour by taking the max value (sum would not be a nice idea for the obvious reasons) for each hour
dataset=busUsageMax(dataset)
dataset
# Out:
#                  timestamp municipality_id usage total_capacity  \
# 0      2017-06-04 07:59:42               0   204           2813
# 1      2017-06-04 07:59:42               1   129            397
# 2      2017-06-04 07:59:42               2   273            697
# 3      2017-06-04 07:59:42               3   623           1930
# 4      2017-06-04 07:59:42               4  1090           3893
# ...                    ...             ...   ...            ...
# 18335  2017-08-19 16:03:35               5   239            587
# 18336  2017-08-19 16:03:35               6  1727           3113
# 18337  2017-08-19 16:03:35               7  1450           2019
# 18338  2017-08-19 16:03:35               8  1253           2947
# 18339  2017-08-19 16:03:35               9   879           1332
#
#       timestampSeconds
# 0           1496559600
# 1           1496559600
# 2           1496559600
# 3           1496559600
# 4           1496559600
# ...                ...
# 18335       1503158400
# 18336       1503158400
# 18337       1503158400
# 18338       1503158400
# 18339       1503158400
#
# [18340 rows x 5 columns]

# %% [markdown]
# "The committee asks you to forecast the hourly bus usages for next week for each municipality.",according to this sentence, we need to identify which feature will be useful to predict the hourly bus usages for each municipality.
# Therefore, only valuable feature in dataset is "usage" for timeseries. Munipality_id and total_capacity (constant for each municipality) are both categorical and non-beneficial. Actually, we can apply feature engineering for municipality_id by generating 10 features represents binary value, but it takes so much time and effort and I don't know that it will be successful for this dataset.So,for simplicity, we will use only usage. Moreover, we should generate one model for only p-one municipality. Because requirement is independent for each  municipality.
# This is an univariate timeseries problem. Hence I will choose one bus to create model. Let's say municipality_id=6. After that, we will do same things specifically and iteratively for other buses.

# %%
selectedMunicipality=6
muniSixthDf=dataset.loc[dataset.municipality_id==selectedMunicipality,["timestampSeconds","usage"]]
muniSixthDf.reset_index(drop=True, inplace=True)
muniSixthDf["usage"]=muniSixthDf["usage"].apply(pd.to_numeric)
muniSixthDf
# Out:
#      timestampSeconds  usage
# 0          1496559600    597
# 1          1496563200    801
# 2          1496566800   1061
# 3          1496570400   1219
# 4          1496574000   1297
# ...               ...    ...
# 1829       1503144000   1787
# 1830       1503147600   1845
# 1831       1503151200   1853
# 1832       1503154800   1829
# 1833       1503158400   1727
#
# [1834 rows x 2 columns]

# %%
#Dataset shows Gaussian Distribution with 10 bins
plt.hist(np.array(muniSixthDf[["usage"]]),bins=10)
# Out:
# (array([  37.,  103.,   92.,  119., 1247.,  144.,   41.,   18.,   18.,
#           15.]),
#  array([ 399. ,  551.1,  703.2,  855.3, 1007.4, 1159.5, 1311.6, 1463.7,
#         1615.8, 1767.9, 1920. ]),
#  <a list of 10 Patch objects>)

# %%
dataStats = muniSixthDf.describe()

dataStats
# Out:
#              usage
# count  1834.000000
# mean   1025.922028
# std     193.035456
# min     399.000000
# 25%    1028.000000
# 50%    1028.000000
# 75%    1028.000000
# max    1920.000000

# %%
xpoints = np.array(muniSixthDf[["timestampSeconds"]])
ypoints = np.array(muniSixthDf[["usage"]])
plt.figure(figsize=(18, 9))
plt.plot(xpoints, ypoints)
#Data has no seasonality or no trend, but frequent value is 1028 and it is the median, also. It seems that we usually forcast the mean.

# %% [markdown]
# One of the most important subject is data partitioning for timeseries problems. The problem wants us to predict the last week. Therefore I will keep the last week as a hold out data, rest of data will be 80% for training and 20% for validation purposes. After we have generated a stable model, we will train our model with both training and validation. Then we will predict the last week which is hold out data.

# %%
def prepareWindowedDataset(series, window_size, batch_size=32,
                           shuffle_buffer=1000):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)

def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %%
series=muniSixthDf.pop('usage')
timestampSeries=muniSixthDf.pop('timestampSeconds')
dataset=pd.DataFrame()
dataset['usage']=series.copy()
#dataset=np.array(dataset)
series=np.array(series)  
time = np.array(timestampSeries)

seriesSize=len(series)
holdoutSize=24*7
splitSize=seriesSize-holdoutSize


splitPoint = int(splitSize * 0.80)

timeTrain = time[:splitPoint]
xTrain = series[:splitPoint]
timeValid = time[splitPoint:-holdoutSize]
xValid = series[splitPoint:-holdoutSize]
timeHoldOut = time[-holdoutSize:]
holdOut = series[-holdoutSize:]
woutHOutSeries=series[:-holdoutSize]

keras.backend.clear_session()
tf.random.set_seed(2022)
np.random.seed(2022)

window_size = 168
train_set = prepareWindowedDataset(xTrain, window_size,
                                   batch_size=200)
valid_set = prepareWindowedDataset(xValid, window_size,
                                   batch_size=200)

holdout_set = prepareWindowedDataset(woutHOutSeries, window_size,
                                   batch_size=200)

# %%
model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for dilation_rate in (1, 2, 4, 8, 10, 14):#, 32
    model.add(
      keras.layers.Conv1D(filters=32,
                          kernel_size=2,
                          strides=1,
                          dilation_rate=dilation_rate,
                          padding="causal",
                          activation="relu")
    )
model.add(keras.layers.Conv1D(filters=1, kernel_size=1))
optimizer = keras.optimizers.Adam(lr=7.5e-5)
model.compile(loss=keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
try:
    model = keras.models.load_model("BestModel.h5")
except:
    pass

model_checkpoint = keras.callbacks.ModelCheckpoint("BestModel.h5",
                                                   monitor='loss',
                                                   save_best_only=True, mode='min')

history = model.fit(train_set, epochs=100,verbose=2, 
                    validation_data=valid_set,
                    callbacks=[model_checkpoint])
# Out:
# Epoch 1/100
# 6/6 - 3s - loss: 49.2814 - mean_absolute_error: 49.7697 - val_loss: 33.1103 - val_mean_absolute_error: 33.5991
# Epoch 2/100
# 6/6 - 2s - loss: 49.2454 - mean_absolute_error: 49.7353 - val_loss: 32.8940 - val_mean_absolute_error: 33.3773
# Epoch 3/100
# 6/6 - 2s - loss: 49.1092 - mean_absolute_error: 49.5979 - val_loss: 32.8912 - val_mean_absolute_error: 33.3781
# Epoch 4/100
# 6/6 - 2s - loss: 49.0494 - mean_absolute_error: 49.5389 - val_loss: 32.8364 - val_mean_absolute_error: 33.3239
# Epoch 5/100
# 6/6 - 2s - loss: 48.9276 - mean_absolute_error: 49.4164 - val_loss: 32.9355 - val_mean_absolute_error: 33.4229
# Epoch 6/100
# 6/6 - 2s - loss: 48.8024 - mean_absolute_error: 49.2911 - val_loss: 32.9482 - val_mean_absolute_error: 33.4364
# Epoch 7/100
# 6/6 - 2s - loss: 48.7341 - mean_absolute_error: 49.2236 - val_loss: 32.8481 - val_mean_absolute_error: 33.3375
# Epoch 8/100
# 6/6 - 2s - loss: 48.7172 - mean_absolute_error: 49.2070 - val_loss: 32.8105 - val_mean_absolute_error: 33.2985
# Epoch 9/100
# 6/6 - 2s - loss: 48.5732 - mean_absolute_error: 49.0624 - val_loss: 32.9480 - val_mean_absolute_error: 33.4344
# Epoch 10/100
# 6/6 - 2s - loss: 48.4868 - mean_absolute_error: 48.9753 - val_loss: 32.9261 - val_mean_absolute_error: 33.4123
# Epoch 11/100
# 6/6 - 2s - loss: 48.4082 - mean_absolute_error: 48.8979 - val_loss: 32.7502 - val_mean_absolute_error: 33.2317
# Epoch 12/100
# 6/6 - 2s - loss: 48.3123 - mean_absolute_error: 48.8002 - val_loss: 32.7348 - val_mean_absolute_error: 33.2138
# Epoch 13/100
# 6/6 - 2s - loss: 48.2114 - mean_absolute_error: 48.6988 - val_loss: 32.8420 - val_mean_absolute_error: 33.3286
# Epoch 14/100
# 6/6 - 2s - loss: 48.1223 - mean_absolute_error: 48.6096 - val_loss: 32.8327 - val_mean_absolute_error: 33.3184
# Epoch 15/100
# 6/6 - 2s - loss: 48.0311 - mean_absolute_error: 48.5172 - val_loss: 32.8065 - val_mean_absolute_error: 33.2922
# Epoch 16/100
# 6/6 - 2s - loss: 47.9310 - mean_absolute_error: 48.4175 - val_loss: 32.8144 - val_mean_absolute_error: 33.3005
# Epoch 17/100
# 6/6 - 2s - loss: 47.8427 - mean_absolute_error: 48.3287 - val_loss: 32.7328 - val_mean_absolute_error: 33.2244
# Epoch 18/100
# 6/6 - 2s - loss: 47.8053 - mean_absolute_error: 48.2944 - val_loss: 32.6874 - val_mean_absolute_error: 33.1767
# Epoch 19/100
# 6/6 - 2s - loss: 47.7076 - mean_absolute_error: 48.1967 - val_loss: 32.7418 - val_mean_absolute_error: 33.2241
# Epoch 20/100
# 6/6 - 2s - loss: 47.5857 - mean_absolute_error: 48.0736 - val_loss: 32.7697 - val_mean_absolute_error: 33.2551
# Epoch 21/100
# 6/6 - 2s - loss: 47.4819 - mean_absolute_error: 47.9687 - val_loss: 32.7049 - val_mean_absolute_error: 33.1899
# Epoch 22/100
# 6/6 - 2s - loss: 47.3954 - mean_absolute_error: 47.8816 - val_loss: 32.6621 - val_mean_absolute_error: 33.1465
# Epoch 23/100
# 6/6 - 2s - loss: 47.3194 - mean_absolute_error: 47.8059 - val_loss: 32.5795 - val_mean_absolute_error: 33.0623
# Epoch 24/100
# 6/6 - 2s - loss: 47.2583 - mean_absolute_error: 47.7465 - val_loss: 32.4768 - val_mean_absolute_error: 32.9620
# Epoch 25/100
# 6/6 - 2s - loss: 47.1940 - mean_absolute_error: 47.6831 - val_loss: 32.4510 - val_mean_absolute_error: 32.9338
# Epoch 26/100
# 6/6 - 2s - loss: 47.0637 - mean_absolute_error: 47.5510 - val_loss: 32.3975 - val_mean_absolute_error: 32.8745
# Epoch 27/100
# 6/6 - 2s - loss: 46.9749 - mean_absolute_error: 47.4613 - val_loss: 32.3654 - val_mean_absolute_error: 32.8453
# Epoch 28/100
# 6/6 - 2s - loss: 46.8840 - mean_absolute_error: 47.3701 - val_loss: 32.4356 - val_mean_absolute_error: 32.9211
# Epoch 29/100
# 6/6 - 2s - loss: 46.7936 - mean_absolute_error: 47.2787 - val_loss: 32.3357 - val_mean_absolute_error: 32.8173
# Epoch 30/100
# 6/6 - 2s - loss: 46.6996 - mean_absolute_error: 47.1842 - val_loss: 32.2720 - val_mean_absolute_error: 32.7550
# Epoch 31/100
# 6/6 - 2s - loss: 46.6082 - mean_absolute_error: 47.0936 - val_loss: 32.1945 - val_mean_absolute_error: 32.6817
# Epoch 32/100
# 6/6 - 2s - loss: 46.5061 - mean_absolute_error: 46.9906 - val_loss: 32.2191 - val_mean_absolute_error: 32.7047
# Epoch 33/100
# 6/6 - 2s - loss: 46.4035 - mean_absolute_error: 46.8882 - val_loss: 32.1357 - val_mean_absolute_error: 32.6217
# Epoch 34/100
# 6/6 - 2s - loss: 46.3142 - mean_absolute_error: 46.8009 - val_loss: 32.2246 - val_mean_absolute_error: 32.7114
# Epoch 35/100
# 6/6 - 2s - loss: 46.1962 - mean_absolute_error: 46.6812 - val_loss: 32.1456 - val_mean_absolute_error: 32.6330
# Epoch 36/100
# 6/6 - 2s - loss: 46.0935 - mean_absolute_error: 46.5794 - val_loss: 31.9734 - val_mean_absolute_error: 32.4573
# Epoch 37/100
# 6/6 - 1s - loss: 45.9713 - mean_absolute_error: 46.4577 - val_loss: 31.9407 - val_mean_absolute_error: 32.4268
# Epoch 38/100
# 6/6 - 2s - loss: 45.8824 - mean_absolute_error: 46.3683 - val_loss: 31.7534 - val_mean_absolute_error: 32.2335
# Epoch 39/100
# 6/6 - 2s - loss: 45.7699 - mean_absolute_error: 46.2554 - val_loss: 31.6907 - val_mean_absolute_error: 32.1724
# Epoch 40/100
# 6/6 - 2s - loss: 45.6726 - mean_absolute_error: 46.1577 - val_loss: 31.6910 - val_mean_absolute_error: 32.1780
# Epoch 41/100
# 6/6 - 2s - loss: 45.5566 - mean_absolute_error: 46.0404 - val_loss: 31.5463 - val_mean_absolute_error: 32.0298
# Epoch 42/100
# 6/6 - 2s - loss: 45.4900 - mean_absolute_error: 45.9762 - val_loss: 31.4870 - val_mean_absolute_error: 31.9715
# Epoch 43/100
# 6/6 - 2s - loss: 45.4145 - mean_absolute_error: 45.9009 - val_loss: 31.3132 - val_mean_absolute_error: 31.7959
# Epoch 44/100
# 6/6 - 2s - loss: 45.3259 - mean_absolute_error: 45.8131 - val_loss: 31.3361 - val_mean_absolute_error: 31.8183
# Epoch 45/100
# 6/6 - 2s - loss: 45.1726 - mean_absolute_error: 45.6558 - val_loss: 31.4332 - val_mean_absolute_error: 31.9137
# Epoch 46/100
# 6/6 - 2s - loss: 45.1608 - mean_absolute_error: 45.6486 - val_loss: 31.0789 - val_mean_absolute_error: 31.5676
# Epoch 47/100
# 6/6 - 2s - loss: 45.0699 - mean_absolute_error: 45.5562 - val_loss: 31.0200 - val_mean_absolute_error: 31.5050
# Epoch 48/100
# 6/6 - 2s - loss: 44.9648 - mean_absolute_error: 45.4509 - val_loss: 30.9794 - val_mean_absolute_error: 31.4659
# Epoch 49/100
# 6/6 - 2s - loss: 44.8675 - mean_absolute_error: 45.3528 - val_loss: 31.0582 - val_mean_absolute_error: 31.5412
# Epoch 50/100
# 6/6 - 2s - loss: 44.7559 - mean_absolute_error: 45.2388 - val_loss: 31.0206 - val_mean_absolute_error: 31.5050
# Epoch 51/100
# 6/6 - 2s - loss: 44.7062 - mean_absolute_error: 45.1919 - val_loss: 30.9986 - val_mean_absolute_error: 31.4813
# Epoch 52/100
# 6/6 - 2s - loss: 44.6217 - mean_absolute_error: 45.1058 - val_loss: 30.8114 - val_mean_absolute_error: 31.2960
# Epoch 53/100
# 6/6 - 2s - loss: 44.5551 - mean_absolute_error: 45.0404 - val_loss: 30.9623 - val_mean_absolute_error: 31.4460
# Epoch 54/100
# 6/6 - 2s - loss: 44.4722 - mean_absolute_error: 44.9567 - val_loss: 30.7438 - val_mean_absolute_error: 31.2253
# Epoch 55/100
# 6/6 - 2s - loss: 44.3928 - mean_absolute_error: 44.8771 - val_loss: 30.8723 - val_mean_absolute_error: 31.3540
# Epoch 56/100
# 6/6 - 2s - loss: 44.3223 - mean_absolute_error: 44.8055 - val_loss: 30.6166 - val_mean_absolute_error: 31.0945
# Epoch 57/100
# 6/6 - 2s - loss: 44.2711 - mean_absolute_error: 44.7572 - val_loss: 30.9126 - val_mean_absolute_error: 31.3975
# Epoch 58/100
# 6/6 - 2s - loss: 44.1837 - mean_absolute_error: 44.6676 - val_loss: 30.5881 - val_mean_absolute_error: 31.0732
# Epoch 59/100
# 6/6 - 2s - loss: 44.0917 - mean_absolute_error: 44.5745 - val_loss: 30.5078 - val_mean_absolute_error: 30.9897
# Epoch 60/100
# 6/6 - 2s - loss: 44.0291 - mean_absolute_error: 44.5133 - val_loss: 30.3862 - val_mean_absolute_error: 30.8682
# Epoch 61/100
# 6/6 - 2s - loss: 43.9663 - mean_absolute_error: 44.4514 - val_loss: 30.4454 - val_mean_absolute_error: 30.9304
# Epoch 62/100
# 6/6 - 2s - loss: 43.8808 - mean_absolute_error: 44.3641 - val_loss: 30.3497 - val_mean_absolute_error: 30.8348
# Epoch 63/100
# 6/6 - 1s - loss: 43.8154 - mean_absolute_error: 44.2993 - val_loss: 30.2892 - val_mean_absolute_error: 30.7726
# Epoch 64/100
# 6/6 - 2s - loss: 43.7332 - mean_absolute_error: 44.2163 - val_loss: 30.1501 - val_mean_absolute_error: 30.6320
# Epoch 65/100
# 6/6 - 2s - loss: 43.6555 - mean_absolute_error: 44.1380 - val_loss: 30.0915 - val_mean_absolute_error: 30.5696
# Epoch 66/100
# 6/6 - 2s - loss: 43.5990 - mean_absolute_error: 44.0822 - val_loss: 30.1725 - val_mean_absolute_error: 30.6583
# Epoch 67/100
# 6/6 - 2s - loss: 43.5377 - mean_absolute_error: 44.0219 - val_loss: 30.0616 - val_mean_absolute_error: 30.5444
# Epoch 68/100
# 6/6 - 2s - loss: 43.4982 - mean_absolute_error: 43.9827 - val_loss: 30.0054 - val_mean_absolute_error: 30.4888
# Epoch 69/100
# 6/6 - 2s - loss: 43.4069 - mean_absolute_error: 43.8912 - val_loss: 29.8013 - val_mean_absolute_error: 30.2810
# Epoch 70/100
# 6/6 - 1s - loss: 43.3400 - mean_absolute_error: 43.8243 - val_loss: 30.1562 - val_mean_absolute_error: 30.6442
# Epoch 71/100
# 6/6 - 2s - loss: 43.2932 - mean_absolute_error: 43.7788 - val_loss: 29.7242 - val_mean_absolute_error: 30.1988
# Epoch 72/100
# 6/6 - 2s - loss: 43.1844 - mean_absolute_error: 43.6686 - val_loss: 29.7098 - val_mean_absolute_error: 30.1934
# Epoch 73/100
# 6/6 - 2s - loss: 43.0982 - mean_absolute_error: 43.5815 - val_loss: 29.7444 - val_mean_absolute_error: 30.2320
# Epoch 74/100
# 6/6 - 1s - loss: 43.0484 - mean_absolute_error: 43.5325 - val_loss: 29.6643 - val_mean_absolute_error: 30.1505
# Epoch 75/100
# 6/6 - 2s - loss: 42.9865 - mean_absolute_error: 43.4702 - val_loss: 29.5612 - val_mean_absolute_error: 30.0438
# Epoch 76/100
# 6/6 - 2s - loss: 42.9323 - mean_absolute_error: 43.4166 - val_loss: 29.4872 - val_mean_absolute_error: 29.9662
# Epoch 77/100
# 6/6 - 2s - loss: 42.8480 - mean_absolute_error: 43.3328 - val_loss: 29.4446 - val_mean_absolute_error: 29.9239
# Epoch 78/100
# 6/6 - 2s - loss: 42.8196 - mean_absolute_error: 43.3044 - val_loss: 29.6814 - val_mean_absolute_error: 30.1630
# Epoch 79/100
# 6/6 - 2s - loss: 42.7494 - mean_absolute_error: 43.2335 - val_loss: 29.3503 - val_mean_absolute_error: 29.8284
# Epoch 80/100
# 6/6 - 2s - loss: 42.6669 - mean_absolute_error: 43.1511 - val_loss: 29.6045 - val_mean_absolute_error: 30.0876
# Epoch 81/100
# 6/6 - 2s - loss: 42.6368 - mean_absolute_error: 43.1215 - val_loss: 29.2478 - val_mean_absolute_error: 29.7269
# Epoch 82/100
# 6/6 - 2s - loss: 42.5329 - mean_absolute_error: 43.0167 - val_loss: 29.3047 - val_mean_absolute_error: 29.7909
# Epoch 83/100
# 6/6 - 2s - loss: 42.4854 - mean_absolute_error: 42.9690 - val_loss: 29.1904 - val_mean_absolute_error: 29.6711
# Epoch 84/100
# 6/6 - 2s - loss: 42.4949 - mean_absolute_error: 42.9802 - val_loss: 29.1136 - val_mean_absolute_error: 29.5937
# Epoch 85/100
# 6/6 - 2s - loss: 42.3874 - mean_absolute_error: 42.8721 - val_loss: 29.1469 - val_mean_absolute_error: 29.6316
# Epoch 86/100
# 6/6 - 2s - loss: 42.2608 - mean_absolute_error: 42.7434 - val_loss: 29.0117 - val_mean_absolute_error: 29.4890
# Epoch 87/100
# 6/6 - 2s - loss: 42.2434 - mean_absolute_error: 42.7276 - val_loss: 29.2427 - val_mean_absolute_error: 29.7290
# Epoch 88/100
# 6/6 - 2s - loss: 42.1777 - mean_absolute_error: 42.6602 - val_loss: 28.9179 - val_mean_absolute_error: 29.3969
# Epoch 89/100
# 6/6 - 2s - loss: 42.1030 - mean_absolute_error: 42.5854 - val_loss: 28.9456 - val_mean_absolute_error: 29.4246
# Epoch 90/100
# 6/6 - 2s - loss: 42.0359 - mean_absolute_error: 42.5190 - val_loss: 28.8438 - val_mean_absolute_error: 29.3220
# Epoch 91/100
# 6/6 - 2s - loss: 41.9899 - mean_absolute_error: 42.4728 - val_loss: 28.7976 - val_mean_absolute_error: 29.2797
# Epoch 92/100
# 6/6 - 2s - loss: 41.9182 - mean_absolute_error: 42.4001 - val_loss: 28.8997 - val_mean_absolute_error: 29.3797
# Epoch 93/100
# 6/6 - 2s - loss: 41.8489 - mean_absolute_error: 42.3309 - val_loss: 28.7985 - val_mean_absolute_error: 29.2772
# Epoch 94/100
# 6/6 - 2s - loss: 41.7975 - mean_absolute_error: 42.2796 - val_loss: 28.6912 - val_mean_absolute_error: 29.1717
# Epoch 95/100
# 6/6 - 2s - loss: 41.7384 - mean_absolute_error: 42.2196 - val_loss: 28.6280 - val_mean_absolute_error: 29.1083
# Epoch 96/100
# 6/6 - 2s - loss: 41.7382 - mean_absolute_error: 42.2215 - val_loss: 28.5884 - val_mean_absolute_error: 29.0705
# Epoch 97/100
# 6/6 - 2s - loss: 41.6221 - mean_absolute_error: 42.1030 - val_loss: 28.7289 - val_mean_absolute_error: 29.2108
# Epoch 98/100
# 6/6 - 2s - loss: 41.5836 - mean_absolute_error: 42.0658 - val_loss: 28.7464 - val_mean_absolute_error: 29.2320
# Epoch 99/100
# 6/6 - 2s - loss: 41.5403 - mean_absolute_error: 42.0231 - val_loss: 28.4450 - val_mean_absolute_error: 28.9255
# Epoch 100/100
# 6/6 - 2s - loss: 41.4523 - mean_absolute_error: 41.9352 - val_loss: 28.3798 - val_mean_absolute_error: 28.8595

# %%
#Now we will train the whole data except for "Hold Out" 
model = keras.models.load_model("BestModel.h5")
history = model.fit(holdout_set, epochs=50,verbose=2,
                    callbacks=[model_checkpoint])
# Out:
# Epoch 1/50
# 8/8 - 2s - loss: 39.7863 - mean_absolute_error: 40.2681
# Epoch 2/50
# 8/8 - 3s - loss: 39.7105 - mean_absolute_error: 40.1925
# Epoch 3/50
# 8/8 - 3s - loss: 39.6532 - mean_absolute_error: 40.1356
# Epoch 4/50
# 8/8 - 3s - loss: 39.5482 - mean_absolute_error: 40.0311
# Epoch 5/50
# 8/8 - 3s - loss: 39.4825 - mean_absolute_error: 39.9648
# Epoch 6/50
# 8/8 - 3s - loss: 39.3970 - mean_absolute_error: 39.8790
# Epoch 7/50
# 8/8 - 3s - loss: 39.3130 - mean_absolute_error: 39.7946
# Epoch 8/50
# 8/8 - 3s - loss: 39.2108 - mean_absolute_error: 39.6915
# Epoch 9/50
# 8/8 - 3s - loss: 39.1400 - mean_absolute_error: 39.6204
# Epoch 10/50
# 8/8 - 3s - loss: 39.0722 - mean_absolute_error: 39.5520
# Epoch 11/50
# 8/8 - 3s - loss: 39.0545 - mean_absolute_error: 39.5358
# Epoch 12/50
# 8/8 - 2s - loss: 38.9392 - mean_absolute_error: 39.4198
# Epoch 13/50
# 8/8 - 3s - loss: 38.8879 - mean_absolute_error: 39.3690
# Epoch 14/50
# 8/8 - 3s - loss: 38.7905 - mean_absolute_error: 39.2695
# Epoch 15/50
# 8/8 - 3s - loss: 38.7638 - mean_absolute_error: 39.2439
# Epoch 16/50
# 8/8 - 3s - loss: 38.7132 - mean_absolute_error: 39.1936
# Epoch 17/50
# 8/8 - 2s - loss: 38.6200 - mean_absolute_error: 39.1002
# Epoch 18/50
# 8/8 - 2s - loss: 38.6831 - mean_absolute_error: 39.1651
# Epoch 19/50
# 8/8 - 2s - loss: 38.6334 - mean_absolute_error: 39.1167
# Epoch 20/50
# 8/8 - 2s - loss: 38.5652 - mean_absolute_error: 39.0478
# Epoch 21/50
# 8/8 - 3s - loss: 38.4621 - mean_absolute_error: 38.9434
# Epoch 22/50
# 8/8 - 3s - loss: 38.4618 - mean_absolute_error: 38.9442
# Epoch 23/50
# 8/8 - 3s - loss: 38.3665 - mean_absolute_error: 38.8479
# Epoch 24/50
# 8/8 - 3s - loss: 38.2813 - mean_absolute_error: 38.7622
# Epoch 25/50
# 8/8 - 3s - loss: 38.2401 - mean_absolute_error: 38.7215
# Epoch 26/50
# 8/8 - 3s - loss: 38.1575 - mean_absolute_error: 38.6378
# Epoch 27/50
# 8/8 - 3s - loss: 38.1037 - mean_absolute_error: 38.5835
# Epoch 28/50
# 8/8 - 2s - loss: 38.1041 - mean_absolute_error: 38.5857
# Epoch 29/50
# 8/8 - 3s - loss: 38.0558 - mean_absolute_error: 38.5363
# Epoch 30/50
# 8/8 - 3s - loss: 37.9494 - mean_absolute_error: 38.4290
# Epoch 31/50
# 8/8 - 2s - loss: 37.9560 - mean_absolute_error: 38.4370
# Epoch 32/50
# 8/8 - 3s - loss: 37.8833 - mean_absolute_error: 38.3639
# Epoch 33/50
# 8/8 - 3s - loss: 37.8321 - mean_absolute_error: 38.3116
# Epoch 34/50
# 8/8 - 3s - loss: 37.7849 - mean_absolute_error: 38.2649
# Epoch 35/50
# 8/8 - 3s - loss: 37.7108 - mean_absolute_error: 38.1895
# Epoch 36/50
# 8/8 - 3s - loss: 37.6625 - mean_absolute_error: 38.1412
# Epoch 37/50
# 8/8 - 3s - loss: 37.6565 - mean_absolute_error: 38.1361
# Epoch 38/50
# 8/8 - 3s - loss: 37.5965 - mean_absolute_error: 38.0761
# Epoch 39/50
# 8/8 - 3s - loss: 37.5719 - mean_absolute_error: 38.0518
# Epoch 40/50
# 8/8 - 2s - loss: 37.4960 - mean_absolute_error: 37.9750
# Epoch 41/50
# 8/8 - 3s - loss: 37.4342 - mean_absolute_error: 37.9129
# Epoch 42/50
# 8/8 - 3s - loss: 37.3940 - mean_absolute_error: 37.8719
# Epoch 43/50
# 8/8 - 3s - loss: 37.3541 - mean_absolute_error: 37.8327
# Epoch 44/50
# 8/8 - 2s - loss: 37.3107 - mean_absolute_error: 37.7888
# Epoch 45/50
# 8/8 - 3s - loss: 37.2537 - mean_absolute_error: 37.7318
# Epoch 46/50
# 8/8 - 2s - loss: 37.2188 - mean_absolute_error: 37.6976
# Epoch 47/50
# 8/8 - 2s - loss: 37.2638 - mean_absolute_error: 37.7447
# Epoch 48/50
# 8/8 - 2s - loss: 37.2163 - mean_absolute_error: 37.6975
# Epoch 49/50
# 8/8 - 2s - loss: 37.1672 - mean_absolute_error: 37.6480
# Epoch 50/50
# 8/8 - 3s - loss: 37.0865 - mean_absolute_error: 37.5662

# %%
model = keras.models.load_model("BestModel.h5")

#cnn_forecast = model_forecast(model, woutHOutSeries[..., np.newaxis], window_size)
#cnn_forecast = cnn_forecast[splitPoint - window_size:, -1, 0]


preds=np.array(woutHOutSeries)
for i in range(holdoutSize):
    try:
        preds=np.append(preds,cnn_forecast[len(cnn_forecast)-1])
    except:
        print("cnn_forecast empthy for first run")
    cnn_forecast = model_forecast(model, preds[..., np.newaxis], window_size)
    cnn_forecast = cnn_forecast[splitPoint - window_size:, -1, 0]


preds=preds[len(preds)-holdoutSize:]

modelDf=pd.DataFrame(columns=['Date','Timestamp','Forecasts','Actual Values'])
modelDf['Forecasts']=preds.copy()
modelDf['Actual Values']=holdOut.copy()
modelDf['Timestamp']=timeHoldOut.copy()
modelDf['Date']=pd.to_datetime(timeHoldOut,unit="s")
# Out:
# cnn_forecast empthy for first run

# %%
modelDf
# Out:
#                    Date   Timestamp    Forecasts  Actual Values
# 0   2017-08-12 17:00:00  1502557200   900.000000           1028
# 1   2017-08-12 18:00:00  1502560800   913.489929           1028
# 2   2017-08-12 19:00:00  1502564400   941.900818           1028
# 3   2017-08-12 20:00:00  1502568000   963.627563           1028
# 4   2017-08-12 21:00:00  1502571600   973.451111           1028
# ..                  ...         ...          ...            ...
# 163 2017-08-19 12:00:00  1503144000   975.254517           1787
# 164 2017-08-19 13:00:00  1503147600   992.162476           1845
# 165 2017-08-19 14:00:00  1503151200  1016.813293           1853
# 166 2017-08-19 15:00:00  1503154800  1042.364502           1829
# 167 2017-08-19 16:00:00  1503158400  1060.399536           1727
#
# [168 rows x 4 columns]

# %%
errors=preds-holdOut
absoluteErrors=np.abs(errors)
mae=absoluteErrors.mean()
mae
# Out:
# 160.2346409388951

# %%
y2 = np.array(modelDf[['Actual Values']])
y1 = np.array(modelDf[['Forecasts']])
x=np.array(modelDf[['Timestamp']])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.figure(figsize=(16, 8))
plt.title("6th Municipality Last Week Forcast", fontdict = font1, loc = 'left')
plt.xlabel("Timestamp(s)", fontdict = font2)
plt.ylabel("Usage", fontdict = font2)
plt.plot(x,y1,label='Forecasts')
plt.plot(x,y2,label='Actual Values')
plt.legend()
plt.show()
